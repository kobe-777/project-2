# %%
import pandas as pd
from pathlib import Path

# %%
application_record_df = pd.read_csv(Path('Resources/application_record.csv'), index_col='ID')
application_record_df
# Out:
#         CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# ID
# 5008804           M            Y               Y             0
# 5008805           M            Y               Y             0
# 5008806           M            Y               Y             0
# 5008808           F            N               Y             0
# 5008809           F            N               Y             0
# ...             ...          ...             ...           ...
# 6840104           M            N               Y             0
# 6840222           F            N               N             0
# 6841878           F            N               N             0
# 6842765           F            N               Y             0
# 6842885           F            N               Y             0
#
#          AMT_INCOME_TOTAL      NAME_INCOME_TYPE  \
# ID
# 5008804          427500.0               Working
# 5008805          427500.0               Working
# 5008806          112500.0               Working
# ...

# %%
credit_record_df = pd.read_csv(Path('Resources/credit_record.csv'), index_col='ID')
credit_record_df
# Out:
#          MONTHS_BALANCE STATUS
# ID
# 5001711               0      X
# 5001711              -1      0
# 5001711              -2      0
# 5001711              -3      0
# 5001712               0      C
# ...                 ...    ...
# 5150487             -25      C
# 5150487             -26      C
# 5150487             -27      C
# 5150487             -28      C
# 5150487             -29      C
#
# [1048575 rows x 2 columns]

# %%
filtered_df1 = application_record_df[application_record_df.index.isin(credit_record_df.index)]
filtered_df2 = credit_record_df[credit_record_df.index.isin(application_record_df.index)]

# %%
filtered_df1
# Out:
#         CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# ID
# 5008804           M            Y               Y             0
# 5008805           M            Y               Y             0
# 5008806           M            Y               Y             0
# 5008808           F            N               Y             0
# 5008809           F            N               Y             0
# ...             ...          ...             ...           ...
# 5149828           M            Y               Y             0
# 5149834           F            N               Y             0
# 5149838           F            N               Y             0
# 5150049           F            N               Y             0
# 5150337           M            N               Y             0
#
#          AMT_INCOME_TOTAL      NAME_INCOME_TYPE  \
# ID
# 5008804          427500.0               Working
# 5008805          427500.0               Working
# 5008806          112500.0               Working
# ...

# %%
filtered_df2.head(60)
# Out:
#          MONTHS_BALANCE STATUS
# ID
# 5008804               0      C
# 5008804              -1      C
# 5008804              -2      C
# 5008804              -3      C
# 5008804              -4      C
# 5008804              -5      C
# 5008804              -6      C
# 5008804              -7      C
# 5008804              -8      C
# 5008804              -9      C
# 5008804             -10      C
# 5008804             -11      C
# 5008804             -12      C
# 5008804             -13      1
# 5008804             -14      0
# 5008804             -15      X
# 5008805               0      C
# 5008805              -1      C
# 5008805              -2      C
# 5008805              -3      C
# 5008805              -4      C
# 5008805              -5      C
# 5008805              -6      C
# 5008805              -7      C
# 5008805              -8      C
# 5008805              -9      C
# 5008805             -10      C
# 5008805             -11      C
# 5008805             -12      1
# ...
